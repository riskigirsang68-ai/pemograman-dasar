# %% [markdown]
# <a href="https://colab.research.google.com/github/riskigirsang68-ai/pemograman-dasar/blob/main/Tugas%20pertemuan_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("="*30)
print("SELAMAT DATANG DI KAFE GEMINI")
print("="*30)
print("Menu Makanan & Minuman:")
print("1. Kopi Hitam  - Rp 12.000")
print("2. Teh Manis   - Rp 8.000")
print("3. Roti Bakar  - Rp 15.000")
print("4. Mie Instan  - Rp 10.000")
print("="*30)

# Pilihan menu
pilihan = int(input("Silakan masukkan nomor pilihan Anda (1-4): "))

nama_pesanan = ""
harga = 0

if pilihan == 1:
    nama_pesanan = "Kopi Hitam"
    harga = 12000
elif pilihan == 2:
    nama_pesanan = "Teh Manis"
    harga = 8000
elif pilihan == 3:
    nama_pesanan = "Roti Bakar"
    harga = 15000
elif pilihan == 4:
    nama_pesanan = "Mie Instan"
    harga = 10000
else:
    print("Maaf, pilihan menu tidak valid. Silakan jalankan ulang program.")

if harga > 0:
    print("="*30)
    print(f"Anda memesan: {nama_pesanan} dengan harga Rp {harga}")

    jumlah = int(input("Masukkan jumlah pesanan: "))
    total_harga = harga * jumlah

    # Pilihan diskon
    print("\nKategori Diskon:")
    print("1. Diskon 70%")
    print("2. Diskon 50%")
    print("3. Diskon 30%")
    print("4. Tidak ada diskon")

    pilih_diskon = int(input("Pilih kategori diskon (1-4): "))

    if pilih_diskon == 1:
        diskon = 0.70
    elif pilih_diskon == 2:
        diskon = 0.50
    elif pilih_diskon == 3:
        diskon = 0.30
    else:
        diskon = 0.0

    potongan = total_harga * diskon
    total_bayar = total_harga - potongan

    print(f"\nTotal Harga Sebelum Diskon: Rp {total_harga}")
    print(f"Diskon: {int(diskon*100)}% (Rp {int(potongan)})")
    print(f"Total Bayar Sesudah Diskon: Rp {int(total_bayar)}")

    uang_dibayar = int(input("\nMasukkan jumlah uang Anda: Rp "))

    if uang_dibayar >= total_bayar:
        kembalian = uang_dibayar - total_bayar
        print("\n--- Struk Pembayaran ---")
        print(f"Pesanan Anda  : {nama_pesanan}")
        print(f"Jumlah        : {jumlah}")
        print(f"Total Harga   : Rp {int(total_harga)}")
        print(f"Diskon        : {int(diskon*100)}% (Rp {int(potongan)})")
        print(f"Total Bayar   : Rp {int(total_bayar)}")
        print(f"Uang Dibayar  : Rp {uang_dibayar}")
        print(f"Kembalian     : Rp {int(kembalian)}")
        print("-------------------------")
        print("Terima kasih telah berbelanja!")
    else:
        kekurangan = total_bayar - uang_dibayar
        print(f"Maaf, uang Anda kurang sebesar Rp {int(kekurangan)}")

print("="*30)
# Out:
# ==============================
# SELAMAT DATANG DI KAFE GEMINI
# ==============================
# Menu Makanan & Minuman:
# 1. Kopi Hitam  - Rp 12.000
# 2. Teh Manis   - Rp 8.000
# 3. Roti Bakar  - Rp 15.000
# 4. Mie Instan  - Rp 10.000
# ==============================
# Silakan masukkan nomor pilihan Anda (1-4): 2
# ==============================
# Anda memesan: Teh Manis dengan harga Rp 8000
# Masukkan jumlah pesanan: 3
#
# Kategori Diskon:
# 1. Diskon 70%
# 2. Diskon 50%
# 3. Diskon 30%
# 4. Tidak ada diskon
# Pilih kategori diskon (1-4): 1
#
# Total Harga Sebelum Diskon: Rp 24000
# Diskon: 70% (Rp 16800)
# Total Bayar Sesudah Diskon: Rp 7200
#
# Masukkan jumlah uang Anda: Rp 60000
#
# --- Struk Pembayaran ---
# Pesanan Anda  : Teh Manis
# Jumlah        : 3
# Total Harga   : Rp 24000
# Diskon        : 70% (Rp 16800)
# Total Bayar   : Rp 7200
# Uang Dibayar  : Rp 60000
# Kembalian     : Rp 52800
# -------------------------
# Terima kasih telah berbelanja!
# ==============================

# %%
print("="*30)
print("SELAMAT DATANG DI KAFE GEMINI")
print("="*30)
print("Menu Makanan & Minuman:")
print("1. Kopi Hitam  - Rp 12.000")
print("2. Teh Manis   - Rp 8.000")
print("3. Roti Bakar  - Rp 15.000")
print("4. Mie Instan  - Rp 10.000")
print("="*30)

# Pilihan menu
pilihan = int(input("Silakan masukkan nomor pilihan Anda (1-4): "))

nama_pesanan = ""
harga = 0

if pilihan == 1:
    nama_pesanan = "Kopi Hitam"
    harga = 12000
elif pilihan == 2:
    nama_pesanan = "Teh Manis"
    harga = 8000
elif pilihan == 3:
    nama_pesanan = "Roti Bakar"
    harga = 15000
elif pilihan == 4:
    nama_pesanan = "Mie Instan"
    harga = 10000
else:
    print("Maaf, pilihan menu tidak valid. Silakan jalankan ulang program.")

if harga > 0:
    print("="*30)
    print(f"Anda memesan: {nama_pesanan} dengan harga Rp {harga}")

    jumlah = int(input("Masukkan jumlah pesanan: "))
    total_harga = harga * jumlah

    # Pilihan diskon
    print("\nKategori Diskon:")
    print("1. Diskon 70%")
    print("2. Diskon 50%")
    print("3. Diskon 30%")
    print("4. Tidak ada diskon")

    pilih_diskon = int(input("Pilih kategori diskon (1-4): "))

    if pilih_diskon == 1:
        diskon = 0.70
    elif pilih_diskon == 2:
        diskon = 0.50
    elif pilih_diskon == 3:
        diskon = 0.30
    else:
        diskon = 0.0

    potongan = total_harga * diskon
    total_bayar = total_harga - potongan

    print(f"\nTotal Harga Sebelum Diskon: Rp {total_harga}")
    print(f"Diskon: {int(diskon*100)}% (Rp {int(potongan)})")
    print(f"Total Bayar Sesudah Diskon: Rp {int(total_bayar)}")

    uang_dibayar = int(input("\nMasukkan jumlah uang Anda: Rp "))

    if uang_dibayar >= total_bayar:
        kembalian = uang_dibayar - total_bayar
        print("\n--- Struk Pembayaran ---")
        print(f"Pesanan Anda  : {nama_pesanan}")
        print(f"Jumlah        : {jumlah}")
        print(f"Total Harga   : Rp {int(total_harga)}")
        print(f"Diskon        : {int(diskon*100)}% (Rp {int(potongan)})")
        print(f"Total Bayar   : Rp {int(total_bayar)}")
        print(f"Uang Dibayar  : Rp {uang_dibayar}")
        print(f"Kembalian     : Rp {int(kembalian)}")
        print("-------------------------")
        print("Terima kasih telah berbelanja!")
    else:
        kekurangan = total_bayar - uang_dibayar
        print(f"Maaf, uang Anda kurang sebesar Rp {int(kekurangan)}")

print("="*30)
# Out:
# ==============================
# SELAMAT DATANG DI KAFE GEMINI
# ==============================
# Menu Makanan & Minuman:
# 1. Kopi Hitam  - Rp 12.000
# 2. Teh Manis   - Rp 8.000
# 3. Roti Bakar  - Rp 15.000
# 4. Mie Instan  - Rp 10.000
# ==============================
# Silakan masukkan nomor pilihan Anda (1-4): 1
# ==============================
# Anda memesan: Kopi Hitam dengan harga Rp 12000
# Masukkan jumlah pesanan: 2
#
# Kategori Diskon:
# 1. Diskon 70%
# 2. Diskon 50%
# 3. Diskon 30%
# 4. Tidak ada diskon
# Pilih kategori diskon (1-4): 2
#
# Total Harga Sebelum Diskon: Rp 24000
# Diskon: 50% (Rp 12000)
# Total Bayar Sesudah Diskon: Rp 12000
#
# Masukkan jumlah uang Anda: Rp 30000
#
# --- Struk Pembayaran ---
# Pesanan Anda  : Kopi Hitam
# Jumlah        : 2
# Total Harga   : Rp 24000
# Diskon        : 50% (Rp 12000)
# Total Bayar   : Rp 12000
# Uang Dibayar  : Rp 30000
# Kembalian     : Rp 18000
# -------------------------
# Terima kasih telah berbelanja!
# ==============================

# %%
print("="*30)
print("SELAMAT DATANG DI KAFE GEMINI")
print("="*30)
print("Menu Makanan & Minuman:")
print("1. Kopi Hitam  - Rp 12.000")
print("2. Teh Manis   - Rp 8.000")
print("3. Roti Bakar  - Rp 15.000")
print("4. Mie Instan  - Rp 10.000")
print("="*30)

# Pilihan menu
pilihan = int(input("Silakan masukkan nomor pilihan Anda (1-4): "))

nama_pesanan = ""
harga = 0

if pilihan == 1:
    nama_pesanan = "Kopi Hitam"
    harga = 12000
elif pilihan == 2:
    nama_pesanan = "Teh Manis"
    harga = 8000
elif pilihan == 3:
    nama_pesanan = "Roti Bakar"
    harga = 15000
elif pilihan == 4:
    nama_pesanan = "Mie Instan"
    harga = 10000
else:
    print("Maaf, pilihan menu tidak valid. Silakan jalankan ulang program.")

if harga > 0:
    print("="*30)
    print(f"Anda memesan: {nama_pesanan} dengan harga Rp {harga}")

    jumlah = int(input("Masukkan jumlah pesanan: "))
    total_harga = harga * jumlah

    # Pilihan diskon
    print("\nKategori Diskon:")
    print("1. Diskon 70%")
    print("2. Diskon 50%")
    print("3. Diskon 30%")
    print("4. Tidak ada diskon")

    pilih_diskon = int(input("Pilih kategori diskon (1-4): "))

    if pilih_diskon == 1:
        diskon = 0.70
    elif pilih_diskon == 2:
        diskon = 0.50
    elif pilih_diskon == 3:
        diskon = 0.30
    else:
        diskon = 0.0

    potongan = total_harga * diskon
    total_bayar = total_harga - potongan

    print(f"\nTotal Harga Sebelum Diskon: Rp {total_harga}")
    print(f"Diskon: {int(diskon*100)}% (Rp {int(potongan)})")
    print(f"Total Bayar Sesudah Diskon: Rp {int(total_bayar)}")

    uang_dibayar = int(input("\nMasukkan jumlah uang Anda: Rp "))

    if uang_dibayar >= total_bayar:
        kembalian = uang_dibayar - total_bayar
        print("\n--- Struk Pembayaran ---")
        print(f"Pesanan Anda  : {nama_pesanan}")
        print(f"Jumlah        : {jumlah}")
        print(f"Total Harga   : Rp {int(total_harga)}")
        print(f"Diskon        : {int(diskon*100)}% (Rp {int(potongan)})")
        print(f"Total Bayar   : Rp {int(total_bayar)}")
        print(f"Uang Dibayar  : Rp {uang_dibayar}")
        print(f"Kembalian     : Rp {int(kembalian)}")
        print("-------------------------")
        print("Terima kasih telah berbelanja!")
    else:
        kekurangan = total_bayar - uang_dibayar
        print(f"Maaf, uang Anda kurang sebesar Rp {int(kekurangan)}")

print("="*30)
# Out:
# ==============================
# SELAMAT DATANG DI KAFE GEMINI
# ==============================
# Menu Makanan & Minuman:
# 1. Kopi Hitam  - Rp 12.000
# 2. Teh Manis   - Rp 8.000
# 3. Roti Bakar  - Rp 15.000
# 4. Mie Instan  - Rp 10.000
# ==============================
# Silakan masukkan nomor pilihan Anda (1-4): 4
# ==============================
# Anda memesan: Mie Instan dengan harga Rp 10000
# Masukkan jumlah pesanan: 4
#
# Kategori Diskon:
# 1. Diskon 70%
# 2. Diskon 50%
# 3. Diskon 30%
# 4. Tidak ada diskon
# Pilih kategori diskon (1-4): 3
#
# Total Harga Sebelum Diskon: Rp 40000
# Diskon: 30% (Rp 12000)
# Total Bayar Sesudah Diskon: Rp 28000
#
# Masukkan jumlah uang Anda: Rp 80000
#
# --- Struk Pembayaran ---
# Pesanan Anda  : Mie Instan
# Jumlah        : 4
# Total Harga   : Rp 40000
# Diskon        : 30% (Rp 12000)
# Total Bayar   : Rp 28000
# Uang Dibayar  : Rp 80000
# Kembalian     : Rp 52000
# -------------------------
# Terima kasih telah berbelanja!
# ==============================
